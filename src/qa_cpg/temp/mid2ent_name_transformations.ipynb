# %% [markdown]
# # mid to name FB15k-237 transformation + analysis

# %%
import os

# %%
test_file = '/Users/georgestoica/Desktop/Research/QA/qa_types/src/qa_cpg/temp/FB15k-237/FB15k-237/test.txt'
train_file = '/Users/georgestoica/Desktop/Research/QA/qa_types/src/qa_cpg/temp/FB15k-237/FB15k-237/train.txt'
files2read = [test_file]
mid2name_path = '/Users/georgestoica/Desktop/mid2name.txt'

# %%
def get_data_from_files(files, mid2name_dict):
    relation_data = {}
    missed_entities = set()
    for file in files:
        with open(file, 'r') as handle:
            for line in handle:
                e1, rel, e2 = line.strip().split('\t')
                if rel not in relation_data:
                    relation_data[rel] = {'e1': set(), 'e2': set()}
                    
                if e1 not in mid2name_dict:
                    missed_entities.add(e1)
                else:
                    e1 = mid2name_dict[e1]
                    relation_data[rel]['e1'].add(e1)
                
                if e2 not in mid2name_dict:
                    missed_entities.add(e2)
                else:
                    e2 = mid2name_dict[e2]
                    relation_data[rel]['e2'].add(e2)
    
    return relation_data, missed_entities

def read_mid2name(mid2name_path):
    mid2name = {}
    with open(mid2name_path, 'r', encoding="utf-8") as handle:
        for line in handle:
            try:
                mid, entity = line.strip().split('\t')
            except:
                continue
            mid2name[mid] = entity
    return mid2name

# %%
mid2name = read_mid2name(mid2name_path)

# %%
named_rel_test_data, missed_test_entities = get_data_from_files(files2read, mid2name)
named_rel_train_data, missed_train_entities = get_data_from_files([train_file], mid2name)

# %%
len(missed_train_entities)
# Out:
# 178

# %%
for idx, relation in enumerate(named_rel_test_data.keys()):
    print(idx, relation)
# Out:
# 0 /ice_hockey/hockey_team/current_roster./sports/sports_team_roster/position
# 1 /medicine/symptom/symptom_of
# 2 /people/cause_of_death/people
# 3 /education/educational_institution/students_graduates./education/education/major_field_of_study
# 4 /base/aareas/schema/administrative_area/administrative_area_type
# 5 /film/film/language
# 6 /education/educational_institution/students_graduates./education/education/student
# 7 /base/popstra/celebrity/dated./base/popstra/dated/participant
# 8 /film/film/edited_by
# 9 /people/person/sibling_s./people/sibling_relationship/sibling
# 10 /education/field_of_study/students_majoring./education/education/major_field_of_study
# 11 /film/film/release_date_s./film/film_regional_release_date/film_release_region
# 12 /user/alexander/philosophy/philosopher/interests
# 13 /sports/sports_team_location/teams
# 14 /education/educational_degree/people_with_this_degree./education/education/major_field_of_study
# 15 /film/film/runtime./film/film_cut/film_release_region
# 16 /location/location/partially_contains
# 17 /film/film_set_designer/film_sets_designed
# 18 /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics
# 19 /tv/tv_program/tv_producer./tv/tv_producer_term/producer_type
# 20 /film/director/film
# 21 /people/person/profession
# 22 /film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance
# 23 /food/food/nutrients./food/nutrition_fact/nutrient
# 24 /film/film/music
# 25 /film/film/executive_produced_by
# 26 /olympics/olympic_games/participating_countries
# 27 /base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months
# 28 /music/performance_role/regular_performances./music/group_membership/role
# 29 /base/americancomedy/celebrity_impressionist/celebrities_impersonated
# 30 /influence/influence_node/peers./influence/peer_relationship/peers
# 31 /olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country
# 32 /organization/organization/headquarters./location/mailing_address/state_province_region
# 33 /base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club
# 34 /education/university/fraternities_and_sororities
# 35 /film/film/personal_appearances./film/personal_film_appearance/person
# 36 /organization/organization_member/member_of./organization/organization_membership/organization
# 37 /film/film/film_art_direction_by
# 38 /film/film/genre
# 39 /education/educational_degree/people_with_this_degree./education/education/student
# 40 /education/educational_degree/people_with_this_degree./education/education/institution
# 41 /organization/organization/child./organization/organization_relationship/child
# 42 /time/event/locations
# 43 /location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source
# 44 /government/politician/government_positions_held./government/government_position_held/jurisdiction_of_office
# 45 /tv/tv_producer/programs_produced./tv/tv_producer_term/program
# 46 /film/film/film_festivals
# 47 /people/deceased_person/place_of_burial
# 48 /tv/tv_program/genre
# 49 /music/artist/origin
# 50 /location/statistical_region/places_exported_to./location/imports_and_exports/exported_to
# 51 /film/film/country
# 52 /soccer/football_team/current_roster./soccer/football_roster_position/position
# 53 /base/eating/practicer_of_diet/diet
# 54 /award/award_winner/awards_won./award/award_honor/award_winner
# 55 /film/film_distributor/films_distributed./film/film_film_distributor_relationship/film
# 56 /people/deceased_person/place_of_death
# 57 /people/person/spouse_s./people/marriage/location_of_ceremony
# 58 /location/hud_county_place/place
# 59 /music/group_member/membership./music/group_membership/role
# 60 /film/film/film_format
# 61 /education/university/domestic_tuition./measurement_unit/dated_money_value/currency
# 62 /travel/travel_destination/climate./travel/travel_destination_monthly_climate/month
# 63 /film/film/cinematography
# 64 /government/political_party/politicians_in_this_party./government/political_party_tenure/politician
# 65 /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location
# 66 /music/instrument/family
# 67 /broadcast/content/artist
# 68 /education/educational_institution/campuses
# 69 /award/award_category/category_of
# 70 /location/administrative_division/country
# 71 /award/award_category/disciplines_or_subjects
# 72 /organization/organization/headquarters./location/mailing_address/country
# 73 /military/military_combatant/military_conflicts./military/military_combatant_group/combatants
# 74 /medicine/disease/risk_factors
# 75 /music/performance_role/track_performances./music/track_contribution/role
# 76 /sports/pro_athlete/teams./sports/sports_team_roster/team
# 77 /base/aareas/schema/administrative_area/administrative_parent
# 78 /film/film/other_crew./film/film_crew_gig/film_crew_role
# 79 /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category
# 80 /film/film_subject/films
# 81 /music/instrument/instrumentalists
# 82 /organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency
# 83 /business/job_title/people_with_this_title./business/employment_tenure/company
# 84 /organization/role/leaders./organization/leadership/organization
# 85 /education/educational_institution/school_type
# 86 /base/locations/continents/countries_within
# 87 /olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics
# 88 /award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee
# 89 /user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy
# 90 /dataworld/gardening_hint/split_to
# 91 /award/award_ceremony/awards_presented./award/award_honor/award_winner
# 92 /people/ethnicity/people
# 93 /people/person/nationality
# 94 /influence/influence_node/influenced_by
# 95 /people/person/spouse_s./people/marriage/type_of_union
# 96 /award/award_nominee/award_nominations./award/award_nomination/award
# 97 /music/group_member/membership./music/group_membership/group
# 98 /film/film/story_by
# 99 /award/award_category/nominees./award/award_nomination/nominated_for
# 100 /base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team
# 101 /tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type
# 102 /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency
# 103 /language/human_language/countries_spoken_in
# 104 /medicine/disease/notable_people_with_this_condition
# 105 /film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium
# 106 /film/film/dubbing_performances./film/dubbing_performance/actor
# 107 /music/record_label/artist
# 108 /base/culturalevent/event/entity_involved
# 109 /education/educational_institution/colors
# 110 /film/film/film_production_design_by
# 111 /award/award_ceremony/awards_presented./award/award_honor/honored_for
# 112 /education/university/local_tuition./measurement_unit/dated_money_value/currency
# 113 /tv/non_character_role/tv_regular_personal_appearances./tv/tv_regular_personal_appearance/person
# 114 /location/hud_county_place/county
# 115 /tv/tv_program/languages
# 116 /olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal
# 117 /user/ktrueman/default_domain/international_organization/member_states
# 118 /organization/organization/place_founded
# 119 /tv/tv_network/programs./tv/tv_network_duration/program
# 120 /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony
# 121 /olympics/olympic_games/sports
# 122 /tv/tv_program/regular_cast./tv/regular_tv_appearance/actor
# 123 /sports/sports_team/roster./american_football/football_roster_position/position
# 124 /sports/sports_league/teams./sports/sports_league_participation/team
# 125 /sports/sports_team/roster./baseball/baseball_roster_position/position
# 126 /film/special_film_performance_type/film_performance_type./film/performance/film
# 127 /organization/organization/headquarters./location/mailing_address/citytown
# 128 /base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed
# 129 /location/country/second_level_divisions
# 130 /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal
# 131 /people/ethnicity/geographic_distribution
# 132 /user/jg/default_domain/olympic_games/sports
# 133 /award/award_category/winners./award/award_honor/award_winner
# 134 /location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency
# 135 /government/politician/government_positions_held./government/government_position_held/legislative_sessions
# 136 /base/biblioness/bibs_location/country
# 137 /people/person/spouse_s./people/marriage/spouse
# 138 /base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer
# 139 /film/actor/dubbing_performances./film/dubbing_performance/language
# 140 /organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency
# 141 /soccer/football_player/current_team./sports/sports_team_roster/team
# 142 /location/statistical_region/religions./location/religion_percentage/religion
# 143 /sports/sports_position/players./sports/sports_team_roster/team
# 144 /location/country/capital
# 145 /base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members
# 146 /award/award_winning_work/awards_won./award/award_honor/award
# 147 /music/artist/contribution./music/recording_contribution/performance_role
# 148 /sports/sports_team/roster./basketball/basketball_roster_position/position
# 149 /base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language
# 150 /travel/travel_destination/how_to_get_here./travel/transportation/mode_of_transportation
# 151 /music/genre/artists
# 152 /people/person/languages
# 153 /award/award_nominee/award_nominations./award/award_nomination/nominated_for
# 154 /sports/sports_team/sport
# 155 /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office
# 156 /award/award_winning_work/awards_won./award/award_honor/honored_for
# 157 /tv/tv_personality/tv_regular_appearances./tv/tv_regular_personal_appearance/program
# 158 /film/actor/film./film/performance/special_performance_type
# 159 /government/legislative_session/members./government/government_position_held/district_represented
# 160 /film/film/release_date_s./film/film_regional_release_date/film_regional_debut_venue
# 161 /music/artist/track_contributions./music/track_contribution/role
# 162 /people/profession/specialization_of
# 163 /location/country/form_of_government
# 164 /government/politician/government_positions_held./government/government_position_held/basic_title
# 165 /location/country/official_language
# 166 /tv/tv_writer/tv_programs./tv/tv_program_writer_relationship/tv_program
# 167 /military/military_conflict/combatants./military/military_combatant_group/combatants
# 168 /film/film/production_companies
# 169 /olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics
# 170 /film/film/prequel
# 171 /music/genre/parent_genre
# 172 /education/educational_institution_campus/educational_institution
# 173 /award/award_nominated_work/award_nominations./award/award_nomination/nominated_for
# 174 /people/person/place_of_birth
# 175 /government/legislative_session/members./government/government_position_held/legislative_sessions
# 176 /base/popstra/celebrity/canoodled./base/popstra/canoodled/participant
# 177 /people/person/employment_history./business/employment_tenure/company
# 178 /music/performance_role/regular_performances./music/group_membership/group
# 179 /soccer/football_team/current_roster./sports/sports_team_roster/position
# 180 /base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency
# 181 /sports/sports_team/colors
# 182 /award/ranked_item/appears_in_ranked_lists./award/ranking/list
# 183 /film/actor/film./film/performance/film
# 184 /film/film/costume_design_by
# 185 /film/film/written_by
# 186 /common/topic/webpage./common/webpage/category
# 187 /sports/sports_team/roster./american_football/football_historical_roster_position/position_s
# 188 /business/business_operation/industry
# 189 /time/event/instance_of_recurring_event
# 190 /location/location/adjoin_s./location/adjoining_relationship/adjoins
# 191 /tv/tv_program/program_creator
# 192 /base/biblioness/bibs_location/state
# 193 /film/film/other_crew./film/film_crew_gig/crewmember
# 194 /sports/sport/pro_athletes./sports/pro_sports_played/athlete
# 195 /organization/organization_founder/organizations_founded
# 196 /tv/tv_program/country_of_origin
# 197 /base/popstra/celebrity/friendship./base/popstra/friendship/participant
# 198 /music/performance_role/guest_performances./music/recording_contribution/performance_role
# 199 /award/award_nominee/award_nominations./award/award_nomination/award_nominee
# 200 /education/field_of_study/students_majoring./education/education/student
# 201 /celebrities/celebrity/celebrity_friends./celebrities/friendship/friend
# 202 /people/person/gender
# 203 /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school
# 204 /film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium
# 205 /location/us_county/county_seat
# 206 /location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency
# 207 /business/business_operation/revenue./measurement_unit/dated_money_value/currency
# 208 /location/location/contains
# 209 /people/person/religion
# 210 /award/award_category/winners./award/award_honor/ceremony
# 211 /people/person/places_lived./people/place_lived/location
# 212 /media_common/netflix_genre/titles
# 213 /sports/sports_league_draft/picks./sports/sports_league_draft_pick/school
# 214 /film/film/estimated_budget./measurement_unit/dated_money_value/currency
# 215 /film/film/produced_by
# 216 /baseball/baseball_team/team_stats./baseball/baseball_team_stats/season
# 217 /award/award_winning_work/awards_won./award/award_honor/award_winner
# 218 /government/governmental_body/members./government/government_position_held/legislative_sessions
# 219 /film/film/featured_film_locations
# 220 /sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft
# 221 /location/location/time_zones
# 222 /film/film/distributors./film/film_film_distributor_relationship/region
# 223 /people/ethnicity/languages_spoken

# %%
relation = '/location/administrative_division/country'
named_rel_train_data[relation]['e1']
# Out:
# {'AU-QLD',
#  'Aberdeen City Police',
#  'Ahnwei',
#  'Aisne (departement)',
#  'Al memzar, dubai',
#  'Alabama (state)',
#  'Alsace, France',
#  'America Samoa',
#  'Amsterdam, The Netherlands',
#  'An Clár (county)',
#  'Ancient City of Aleppo',
#  'Andhara Pradesh',
#  'Anglo-Aquitanian',
#  'Argyll and Bute Council',
#  'Arizona department of commerce',
#  'Army of Vanuatu',
#  'Arunacal Prades',
#  'Asia/Jakarta',
#  'Assam (India)',
#  'Aude (department)',
#  'Austin City Connection',
#  "Australia's state of Victoria",
#  'Australian capital territory',
#  'B. Aires',
#  'Baki Sahari, Azerbaijan',
#  'Ballinlough, County Meath',
#  'Balochistān (Pakistan)',
#  'Barcellona',
#  'Barcelona (province)',
#  'Bas Rhin',
#  'Basse-Normandie',
#  'Bavarians',
#  "Bec-d'Ambès",
#  'Bengal, West',
#  'Bihar, India',
#  'Bordelaise',
#  'Bourgogne',
#  'Braniborsko',
#  'Bucharest, Romania',
#  'Buckeye State',
#  'Budapest, Hungary',
#  'Buenos Aires province',
#  'CA-ON',
#  'Caerdydd (county borough)',
#  'Cagliari Province',
#  'Calatria',
#  'Cambaleth',
#  'Canal de las Estrellas U.S.A',
#  'Cannes, France',
#  'Canton Ticino',
#  'Canton of Aargau',
#  'Canton of Zuerich',
#  'Canton of bern',
#  'Cape Verdian',
#  'Capital of Latvia',
#  'Capital of Qatar',
#  'Carlton Primary School',
#  'Category West Midlands',
#  'Champagne Ardennes',
#  'Chandigarh Administration',
#  'Chatgaon',
#  'Cheng Du',
#  'Cheshire (England)',
#  'Chhatisgarh State',
#  'Chongqing Municipality',
#  'Cill Mhantáin (county)',
#  'Cisjordania',
#  'City of Discovery',
#  'City of Glasgow, Scotland',
#  'City of Plymouth',
#  'City of Stoke on Trent',
#  'City of Westminister Act 1999',
#  'City of York',
#  'City of a thousand trades',
#  'Climate of Montana',
#  'Co Galway',
#  'Co Monaghan',
#  'Co. Kerry',
#  'Co. Limerick',
#  'Commonwealth of Massachusetts',
#  'Constituicao',
#  'Constitution State',
#  'Corn Wall',
#  'Corsic',
#  'County Borough of Bradford',
#  'County Borough of Bristol',
#  'County Borough of Merthyr Tydfil',
#  'County Borough of Newcastle upon Tyne',
#  'County Borough of Nottingham',
#  'County Borough of Swansea',
#  'County Dublin, Ireland',
#  'County Tyrconnel',
#  'County antrim',
#  'County of Kent, England',
#  'County of Lancaster',
#  'Coventry City council',
#  'Cumbria, England',
#  'Cuneo Province',
#  'Deise',
#  'Delawarean',
#  'Demographics of Michigan',
#  'Denedeh',
#  'Department of Calvados',
#  'Department of Dordogne',
#  'Derbys',
#  'Districts of Upper Austria',
#  'Dorset, England',
#  'Dumfries and Galloway Council',
#  'Durham County Council',
#  'Départment of Alpes-Maritimes',
#  'East Gwynedd',
#  'East Sussex, England',
#  'Education in Iowa',
#  'Eidyn',
#  'England Hull',
#  'Escocia',
#  'Essex primary school',
#  'Estado Libre y Soberano de Chihuahua',
#  'Estado Libre y Soberano de Sonora',
#  'FRPAR',
#  'Fatehpur beri',
#  'Fauna of Western Australia',
#  'Flying Handbag',
#  'Foreign relations of New Caledonia',
#  'Foroyar',
#  'Fourth State',
#  'Free City of Hamburg',
#  'French Establishments in Oceania',
#  'Friesland, Netherlands',
#  'Fuhkien',
#  'Fukushima prefecture',
#  'Geography of madhya pradesh',
#  'Gibraltar 300',
#  'Gifu, Japan',
#  'Gloucestershire County Council',
#  'Goa Pradesh',
#  'Government of Carinthia (state)',
#  'Government of Nunavut',
#  'Government of Vienna',
#  'Gravenhage',
#  'Groningen province',
#  'Guangdon',
#  'Guelderland',
#  'Gujurat',
#  'Hackney (borough)',
#  'Harare, Zimbabwe',
#  'Harayana',
#  'Hartlepool monkey',
#  'Hertfordshire, UK',
#  'Hesse, Germany',
#  'Hilly Shore',
#  'HimachalPradesh',
#  'History of Surrey',
#  'Hokkaidou',
#  'Hyderabad city',
#  'IN-KL',
#  'ISO 3166-1:AW',
#  'Ibaragi Oni',
#  'Indian Kashmir',
#  'Island of Jersey',
#  'Isle of Man/Military',
#  'Isle of Wight UA',
#  'JP-34',
#  'JP-40',
#  'Jalisco, Mexico',
#  'Jarkhand',
#  'Jiangsu, China',
#  'Johns River Public School',
#  'KS, USA',
#  'Kamaynilaan',
#  'Kao-hsiung',
#  'Karnātakā',
#  'Khyber Pukhtoonkhwa',
#  'Kilkenny County',
#  'Kingdom of Sugbo',
#  'Kinshasa, Congo',
#  'Kobenhavn',
#  'Krung-dēvamahānagara amararatanakosindra mahindrayudhyā mahātilakabhava navaratanarājadhānī purīrāmasya utamarājanivēsana mahāsthāna amaravimāna avatārasthitya shakrasdattiya vishnukarmaprasiddhi',
#  'Kyŏnggi',
#  'L-Town',
#  'La Colombie-Britannique',
#  'La Habana, Cuba',
#  'Landschaftsverband',
#  'Laughlin City',
#  'Leicester, UK',
#  'Leics',
#  'Liaoning Province, China',
#  'Libertas Quae Sera Tamen',
#  'Limburg (Dutch province)',
#  'London (region)',
#  'Lorraine (region, France)',
#  'Ludowingians',
#  'Lupanlunti',
#  'Lyonais',
#  'MTQ',
#  'MX-VER',
#  'Maharashtra State, India',
#  'Maigh Eo (county)',
#  'Manchester (borough)',
#  'Manilan',
#  'Manipur State',
#  'Marseilles, France',
#  'Maryland (U.S. state)',
#  'Massachusetts/Boston',
#  'Mecklenburg-Western Pommerania',
#  'Melaka (state)',
#  'Melbouren',
#  'Micronesia/Military',
#  'Military of the Cook Islands',
#  'Miyagi-ken',
#  'Monmouthshire (administrative)',
#  'Moskou',
#  'Moskva Oblast',
#  'Mpuma-Koloni',
#  'Muenchen, Germany',
#  'Na Se Contaethe',
#  'Napoli Province',
#  'Nelson, Nelson',
#  'New Jersey, United States',
#  'New Orleans, Louisiana, U.S.A.',
#  'New york city, new york',
#  'Newfoundland and labrador',
#  'Newport, Gwent, Wales',
#  'Niederoesterreich',
#  'Nize',
#  'Noord Holland',
#  'Nord, France',
#  'Nord-Pas de Calais',
#  'Norfolk, UK',
#  'North Cackalack',
#  'North-Brabant',
#  'Northants',
#  'Northumberland (England)',
#  'Nouveau-Brunswick',
#  'Nova scosia',
#  'Oaxaca State',
#  'Odesa, Ukraine',
#  'Old Dhaka',
#  'Old Mexico',
#  'Oregroun',
#  'Oslo, Norway',
#  'Overyssel',
#  'Pampanga Province',
#  'Pangasinan (province)',
#  'Pas De Calais',
#  'Pchjongjang',
#  'Pearl of Asia',
#  'Pennslyvania',
#  "People's Republic of Vermont",
#  'Perak ur-Ridzwan',
#  'Perth & Kinross Region',
#  'Pince edward island',
#  'Podlachian Voivodeship',
#  'Politics of Idaho',
#  'Politics of Kentucky',
#  'Poole, Dorset',
#  'Port of Spain City Corporation',
#  'Potenza Province',
#  'Province of Utrecht',
#  'Province of como',
#  'Province of turin',
#  'Provincia di Milano',
#  'Provincia di Trento',
#  'Provinsi Jawa Tengah',
#  'Punjab (Indian state)',
#  'Punjab Pakistan',
#  'Pusan, Korea',
#  'Qirim',
#  'Queens County, Ireland',
#  'Quezón City',
#  'Reading England',
#  'Rebel County',
#  'Regiao Administrativa Especial de Macau da Republica Popular da China',
#  'Region bruxelles-capitale',
#  'Region of Brittany',
#  'Religion in Nevada',
#  'Republic of Brescia',
#  'Rest of Virginia',
#  'Rhineland Pfalz',
#  'Rhode Island cuisine',
#  'Rhosygadfa',
#  'Rio Grande do Sul, Brazil',
#  'Rockford Academy',
#  'Sabah, Malaysia',
#  'Salerno Province',
#  'Salzburg state',
#  'Santa Fe Province, Argentina',
#  'Sask.',
#  'Saxony Anhalt',
#  'Schleswig–Holstein',
#  'Seine-Et-Marne',
#  'Selangor, Malaysia',
#  'Shandong province',
#  'Shang Hai',
#  'Shang gang',
#  'Shansi Province',
#  'Sheffield england',
#  'Shenshi',
#  'Shizuoka, Japan',
#  'Shligigh',
#  'SinKiang',
#  'Sindh (Province)',
#  'Somme Département',
#  'South Australian',
#  'South Tyroleans',
#  'South-Holland',
#  'Southend-on-sea',
#  'State of Johor',
#  'State of Wyoming',
#  'State of new yourk',
#  'Steiermark',
#  'Sud de France',
#  'Suffolk, England',
#  'Swobodny Stat Sakska',
#  'Taegu Metropolitan City, South Korea',
#  'Taskent',
#  'Tasmania - Australia',
#  'Texas (state)',
#  'The Aloha State',
#  'The City That Knows How',
#  'The Island of the Gods',
#  'The Palmetto State',
#  'The Premier County',
#  'The Western Cape',
#  'The city of dreaming spires',
#  'The weather in Middlesbrough',
#  'The weather in Southampton',
#  'Tower Hamlets',
#  'Town (Alaska)',
#  'Town of Somerset',
#  "Tp'ilisi",
#  'Transport in Maine',
#  'Transport in New Mexico',
#  'Transport in Utah',
#  'Transport in Washington',
#  'Transportation in Nebraska',
#  'Tripoli, Libya',
#  'Tunes, Tunisia',
#  'Táibèi',
#  'Tāmaki Makau Rau',
#  'UN/LOCODE:MXMEX',
#  'US-CO',
#  'US-GU',
#  'US-MO',
#  'US-NH',
#  'US-OK',
#  'Upper Savoy',
#  'Uttar Pardesh',
#  'Uttarkhand',
#  'VA Arlington',
#  'Vaucluse (département)',
#  'Voivode of Lublin',
#  'Voivode of Mazowsze',
#  'Voivode of Pomorze',
#  'Voivodship wielkopolskie',
#  'Waadt',
#  'Wakefield, West Yorkshire',
#  'Wallis canton',
#  'Warrington (district)',
#  'Warwickshire County Council',
#  'Wasington, DC',
#  'Wellington, NZ',
#  'West Dublin',
#  'West Yorkshire, England',
#  'West virginia',
#  'Wexford Corporation',
#  'Willingham Green',
#  'Wiltshire, England',
#  'Wrench Green',
#  "Wright's Green",
#  'Wulfrunians',
#  'Yukon Territory',
#  'Yvelines',
#  'Yún nán',
#  'Yü',
#  'Zulu-Natal',
#  'Ænglaland',
#  'བོད་',
#  '’Derry',
#  '埼玉県',
#  '愛知県',
#  '武漢',
#  '神奈川',
#  '長野県',
#  '서울'}

# %%
named_rel_train_data[relation]['e2']
# Out:
# {'Al Hind',
#  'Al-Jumhūriyya at-Tūnisiyya',
#  'Army of Vanuatu',
#  'Arxentina',
#  'Aussieland',
#  'Austrian Republic',
#  'Azerbaydzhan',
#  'Belgique',
#  'Brazília',
#  'Cape Verdian',
#  'Chinese civilisation',
#  'Confédération Suisse',
#  'Congo DR',
#  'Denmarc',
#  'Federation of Malaysia',
#  'Foroyar',
#  'Gurcistan',
#  'ITALY',
#  'Ireland/Éire',
#  'Islamic Republic Of Pakistan',
#  'Japón',
#  'Jermany',
#  'Kenadian',
#  'Kingdom of Kampuchea',
#  'Kingdom of Spain',
#  'Kingdom of Thailand',
#  'Korea (Pyongyang)',
#  'Lehabim',
#  'Letonia',
#  'Metropolitan Netherlands',
#  'Micronesia/Military',
#  'N z',
#  'Name of Cuba',
#  'Ouzbékistan',
#  'Philippine archipelago',
#  'Polskor',
#  'Portuga',
#  'Purangsu',
#  'Republic of China (1912-49)',
#  'Republic of Korea',
#  'Republic of Mexico',
#  'Roemenië',
#  'Souria',
#  'South African',
#  'The Kingdom of the Netherlands',
#  'The Russian federation',
#  'Trinidad & Tobago',
#  'U.A. Emirates',
#  'UK of GB and NI',
#  'UKR',
#  'Ungheria',
#  'Unitary state of the republic of indonesia',
#  'Yankee land',
#  'Zimbabwei',
#  'Ænglaland',
#  'הרשות הפלסטינית',
#  'دولة قطر',
#  'গনপ্রজাতন্ত্রী বাংলােদশ',
#  '挪威'}
